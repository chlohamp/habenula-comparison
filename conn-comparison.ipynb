# %%
import os
import os.path as op
import numpy as np
import nibabel as nib
import pandas as pd
from nilearn.maskers import NiftiMasker
from nilearn import datasets, image
from nilearn.image import threshold_img
from scipy import stats

# %% [markdown]
# ## Define Dice Coefficient Function
# The Dice coefficient measures the overlap between two binary masks, ranging from 0 (no overlap) to 1 (perfect overlap).

# %%
def dice_coefficient(mask1_nii, mask2_nii):
    """
    Calculate Dice similarity coefficient between two binary masks.
    
    Dice = 2 * |X ∩ Y| / (|X| + |Y|)
    
    Parameters:
    -----------
    mask1_nii, mask2_nii : str
        Paths to NIfTI files containing masks (1D or 3D arrays)
    brain_mask : array-like, optional
        Binary mask to restrict analysis to brain voxels
    
    Returns:
    --------
    dice : float
        Dice coefficient (0-1)
    """
    # Load two binary segmentation maps
    mask1 = image.load_img(mask1_nii)
    mask2 = image.load_img(mask2_nii)

    # Print unique values in the original masks before any resampling/binarization
    print(f"Unique values in original mask1: {np.unique(mask1.get_fdata())}")
    print(f"Unique values in original mask2: {np.unique(mask2.get_fdata())}")

    # Ensure they are binary
    mask1_data = (mask1.get_fdata() > 0).astype(int)
    mask2_data = (mask2.get_fdata() > 0).astype(int)

    # Print unique values
    print(f"Unique values in mask1_data: {np.unique(mask1_data)}")
    print(f"Unique values in mask2_data: {np.unique(mask2_data)}")

    # Calculate intersection and volumes
    intersection = np.logical_and(mask1_data, mask2_data).sum()
    volume_sum = mask1_data.sum() + mask2_data.sum()

    # Dice Coefficient
    dice = 2. * intersection / volume_sum
    return dice

# %%
from scipy.stats import pearsonr

def pearson_correlation(mask1_nii, mask2_nii):
    """
    Calculate Pearson correlation between two mask matrices.

    Parameters:
    -----------
    mask1_nii, mask2_nii : str
        Paths to NIfTI files containing masks

    Returns:
    --------
    r : float
        Pearson correlation coefficient (-1 to 1)
    p_value : float
        Two-tailed p-value for the correlation
    """
    # Load segmentation maps
    mask1 = image.load_img(mask1_nii)
    mask2 = image.load_img(mask2_nii)

    # Print unique values in original masks
    print(f"Unique values in original mask1: {np.unique(mask1.get_fdata())}")
    print(f"Unique values in original mask2: {np.unique(mask2.get_fdata())}")

    # Flatten full matrices for correlation
    mask1_data = mask1.get_fdata().ravel()
    mask2_data = mask2.get_fdata().ravel()

    if mask1_data.size < 2:
        return np.nan, np.nan

    # Pearson is undefined for constant vectors
    if np.std(mask1_data) == 0 or np.std(mask2_data) == 0:
        return np.nan, np.nan

    r, pvalue = pearsonr(mask1_data, mask2_data, method=stats.MonteCarloMethod(n_resamples=10))
    return r, pvalue

# %%
from scipy.stats import spearmanr

def spearman_correlation(mask1_nii, mask2_nii):
    """
    Calculate Spearman correlation between two mask matrices.

    Parameters:
    -----------
    mask1_nii, mask2_nii : str
        Paths to NIfTI files containing masks

    Returns:
    --------
    r : float
        Spearman correlation coefficient (-1 to 1)
    p_value : float
        Two-tailed p-value for the correlation
    """
    # Load segmentation maps
    mask1 = image.load_img(mask1_nii)
    mask2 = image.load_img(mask2_nii)

    # Print unique values in original masks
    print(f"Unique values in original mask1: {np.unique(mask1.get_fdata())}")
    print(f"Unique values in original mask2: {np.unique(mask2.get_fdata())}")

    # Flatten full matrices for correlation
    mask1_data = mask1.get_fdata().ravel()
    mask2_data = mask2.get_fdata().ravel()

    if mask1_data.size < 2:
        return np.nan, np.nan

    # Pearson is undefined for constant vectors
    if np.std(mask1_data) == 0 or np.std(mask2_data) == 0:
        return np.nan, np.nan

    r = spearmanr(mask1_data, mask2_data)
    return r

# %% [markdown]
# ## Setup Directories and Masker

# %%
data_dir = "./dset"
deriv_dir = op.join(data_dir, "derivatives")
analysis_dir = op.join(deriv_dir, "hb-conn")

# Setup masker
mask_img = datasets.load_mni152_brain_mask(resolution=2)
masker = NiftiMasker(mask_img=mask_img)
masker = masker.fit()

# Load MNI152 template to use as brain mask
template_img = datasets.load_mni152_template(resolution=2)
template_data = template_img.get_fdata()
brain_mask = (template_data != 0).astype(int)

print(f"Brain mask shape: {brain_mask.shape}")
print(f"Brain voxels: {np.sum(brain_mask)}")
# Out:
# Brain mask shape: (99, 117, 95)
# Brain voxels: 502207

# %% [markdown]
# ## Define File Paths

# %%
# Group directories
group_drawn_dir = op.join(analysis_dir, "group-drawn/habenula")
group_atlas_dir = op.join(analysis_dir, "group-atlas/habenula")

# File paths for group average (1-sample) maps
drawn_1s_nii = op.join(group_drawn_dir, "averaged", "sub-group_task-rest_desc-1SampletTest_thresh.nii.gz")
atlas_1s_nii = op.join(group_atlas_dir, "averaged", "sub-group_task-rest_desc-1SampletTest_thresh.nii.gz")
# File paths for group comparison (2-sample) maps
drawn_2s_nii = op.join(group_drawn_dir, "difference", "sub-group_task-rest_desc-2SampletTest_thresh.nii.gz")
atlas_2s_nii = op.join(group_atlas_dir, "difference", "sub-group_task-rest_desc-2SampletTest_thresh.nii.gz")

print("File paths defined:")
print(f"Drawn 1-sample: {drawn_1s_nii}")
print(f"Atlas 1-sample: {atlas_1s_nii}")
print(f"Drawn 2-sample: {drawn_2s_nii}")
print(f"Atlas 2-sample: {atlas_2s_nii}")
# Out:
# File paths defined:
# Drawn 1-sample: ./dset/derivatives/hb-conn/group-drawn/habenula/averaged/sub-group_task-rest_desc-1SampletTest_thresh.nii.gz
# Atlas 1-sample: ./dset/derivatives/hb-conn/group-atlas/habenula/averaged/sub-group_task-rest_desc-1SampletTest_thresh.nii.gz
# Drawn 2-sample: ./dset/derivatives/hb-conn/group-drawn/habenula/difference/sub-group_task-rest_desc-2SampletTest_thresh.nii.gz
# Atlas 2-sample: ./dset/derivatives/hb-conn/group-atlas/habenula/difference/sub-group_task-rest_desc-2SampletTest_thresh.nii.gz

# %% [markdown]
# ## Calculate Stats for Group Average Maps (1-Sample)

# %%
dice_1s = dice_coefficient(drawn_1s_nii, atlas_1s_nii)
 
print(f"1-sample Dice coefficient: {dice_1s:.4f}")
# Out:
# Unique values in original mask1: [-7.31994009 -7.25499535 -7.05353403 ... 25.97607994 26.43304825
#  28.04886055]
# Unique values in original mask2: [-9.01842785 -8.90839577 -8.70893574 ... 36.87558365 37.27815628
#  38.05744171]
# Unique values in mask1_data: [0 1]
# Unique values in mask2_data: [0 1]
# 1-sample Dice coefficient: 0.8094

# %%
# Calculate binary Dice coefficient restricted to brain voxels via brain_mask
pearsonr_1s = pearson_correlation(drawn_1s_nii, atlas_1s_nii)
 
print(f"1-sample Pearson correlation: {pearsonr_1s[0]:.4f}, P-value: {pearsonr_1s[1]:.10f}")
# Out:
# Unique values in original mask1: [-7.31994009 -7.25499535 -7.05353403 ... 25.97607994 26.43304825
#  28.04886055]
# Unique values in original mask2: [-9.01842785 -8.90839577 -8.70893574 ... 36.87558365 37.27815628
#  38.05744171]
# 1-sample Pearson correlation: 0.8830, P-value: 0.1818181818

# %%
# Calculate binary Dice coefficient restricted to brain voxels via brain_mask
spearmanr_1s = spearman_correlation(drawn_1s_nii, atlas_1s_nii)
 
print(f"1-sample Spearman correlation: {spearmanr_1s[0]:.4f}")
# Out:
# Unique values in original mask1: [-7.31994009 -7.25499535 -7.05353403 ... 25.97607994 26.43304825
#  28.04886055]
# Unique values in original mask2: [-9.01842785 -8.90839577 -8.70893574 ... 36.87558365 37.27815628
#  38.05744171]
# 1-sample Spearman correlation: 0.8188

# %% [markdown]
# ## Calculate Stats for Group Difference Maps (2-Sample)
#
# ### (ASD>NT)

# %%
# Calculate binary Dice coefficient restricted to brain voxels via brain_mask
dice_2s = dice_coefficient(drawn_2s_nii, atlas_2s_nii)
 
print(f"2-sample Dice coefficient: {dice_2s:.4f}")
# Out:
# Unique values in original mask1: [0.         3.89323449 3.89559269 3.90370703 3.90612149 3.90988231
#  3.91043162 3.91045022 3.91052985 3.91086698 3.91113544 3.91133928
#  3.9187839  3.91910839 3.92197514 3.92688656 3.93213296 3.93570161
#  3.93868661 3.94650888 3.94793057 3.95044446 3.9549458  3.95889544
#  3.96082139 3.96486616 3.96698332 3.96991038 3.97396326 3.9746654
#  3.97646952 3.98059559 3.98389721 3.98982072 3.99092555 3.99985981
#  4.00188828 4.00441074 4.00597954 4.006495   4.00834608 4.00895452
#  4.01236343 4.01432705 4.02813816 4.03069353 4.03440762 4.04094219
#  4.04151058 4.04671717 4.04925919 4.04965734 4.05028963 4.05685043
#  4.05815458 4.05978394 4.06178474 4.0628438  4.06824112 4.06923389
#  4.06997299 4.07009459 4.07270336 4.07464504 4.07731962 4.07933569
#  4.07948446 4.08216953 4.08291101 4.0853343  4.08653498 4.08737183
#  4.09142637 4.10147572 4.10585117 4.10729074 4.1087513  4.10924578
#  4.11298418 4.11401653 4.11846113 4.12386608 4.12390137 4.12618637
# ...

# %%
# Calculate binary Dice coefficient restricted to brain voxels via brain_mask
pearsonr_2s = pearson_correlation(drawn_2s_nii, atlas_2s_nii)
 
print(f"2-sample Pearson correlation: {pearsonr_2s[0]:.4f}, P-value: {pearsonr_2s[1]:.10f}")
# Out:
# Unique values in original mask1: [0.         3.89323449 3.89559269 3.90370703 3.90612149 3.90988231
#  3.91043162 3.91045022 3.91052985 3.91086698 3.91113544 3.91133928
#  3.9187839  3.91910839 3.92197514 3.92688656 3.93213296 3.93570161
#  3.93868661 3.94650888 3.94793057 3.95044446 3.9549458  3.95889544
#  3.96082139 3.96486616 3.96698332 3.96991038 3.97396326 3.9746654
#  3.97646952 3.98059559 3.98389721 3.98982072 3.99092555 3.99985981
#  4.00188828 4.00441074 4.00597954 4.006495   4.00834608 4.00895452
#  4.01236343 4.01432705 4.02813816 4.03069353 4.03440762 4.04094219
#  4.04151058 4.04671717 4.04925919 4.04965734 4.05028963 4.05685043
#  4.05815458 4.05978394 4.06178474 4.0628438  4.06824112 4.06923389
#  4.06997299 4.07009459 4.07270336 4.07464504 4.07731962 4.07933569
#  4.07948446 4.08216953 4.08291101 4.0853343  4.08653498 4.08737183
#  4.09142637 4.10147572 4.10585117 4.10729074 4.1087513  4.10924578
#  4.11298418 4.11401653 4.11846113 4.12386608 4.12390137 4.12618637
# ...

# %%
# Calculate binary Dice coefficient restricted to brain voxels via brain_mask
spearmanr_2s = spearman_correlation(drawn_2s_nii, atlas_2s_nii)
 
print(f"2-sample Spearman correlation: {spearmanr_2s[0]:.4f}")
# Out:
# Unique values in original mask1: [0.         3.89323449 3.89559269 3.90370703 3.90612149 3.90988231
#  3.91043162 3.91045022 3.91052985 3.91086698 3.91113544 3.91133928
#  3.9187839  3.91910839 3.92197514 3.92688656 3.93213296 3.93570161
#  3.93868661 3.94650888 3.94793057 3.95044446 3.9549458  3.95889544
#  3.96082139 3.96486616 3.96698332 3.96991038 3.97396326 3.9746654
#  3.97646952 3.98059559 3.98389721 3.98982072 3.99092555 3.99985981
#  4.00188828 4.00441074 4.00597954 4.006495   4.00834608 4.00895452
#  4.01236343 4.01432705 4.02813816 4.03069353 4.03440762 4.04094219
#  4.04151058 4.04671717 4.04925919 4.04965734 4.05028963 4.05685043
#  4.05815458 4.05978394 4.06178474 4.0628438  4.06824112 4.06923389
#  4.06997299 4.07009459 4.07270336 4.07464504 4.07731962 4.07933569
#  4.07948446 4.08216953 4.08291101 4.0853343  4.08653498 4.08737183
#  4.09142637 4.10147572 4.10585117 4.10729074 4.1087513  4.10924578
#  4.11298418 4.11401653 4.11846113 4.12386608 4.12390137 4.12618637
# ...

# %% [markdown]
# ## Define Spearman Correlation Function
# The Spearman correlation measures the monotonic relationship between two continuous (thresholded) masks.

# %%
from scipy.stats import spearmanr

def spearman_correlation(mask1, mask2, brain_mask=None, method='overlap'):
    """
    Calculate Spearman correlation between two thresholded masks.
    
    Parameters:
    -----------
    mask1, mask2 : array-like
        Continuous masks (1D or 3D arrays) - typically thresholded statistical maps
    brain_mask : array-like, optional
        Binary mask to restrict analysis to brain voxels
    method : str, default='overlap'
        'overlap': correlate only where both masks are non-zero (RECOMMENDED)
        'union': correlate where either mask is non-zero
        'all': correlate all brain voxels (if brain_mask provided)
    
    Returns:
    --------
    correlation : float
        Spearman correlation coefficient (-1 to 1)
    p_value : float
        Two-tailed p-value for the correlation
    """
    # Flatten arrays if needed
    mask1_flat = mask1.flatten()
    mask2_flat = mask2.flatten()
    
    # Apply brain mask if provided
    if brain_mask is not None:
        brain_mask_flat = brain_mask.flatten().astype(bool)
        mask1_flat = mask1_flat[brain_mask_flat]
        mask2_flat = mask2_flat[brain_mask_flat]
    
    # Select voxels based on method
    if method == 'overlap':
        # Only correlate where BOTH masks are non-zero
        valid_mask = (mask1_flat != 0) & (mask2_flat != 0)
    elif method == 'union':
        # Correlate where EITHER mask is non-zero
        valid_mask = (mask1_flat != 0) | (mask2_flat != 0)
    elif method == 'all':
        # Use all voxels (requires brain_mask to be meaningful)
        valid_mask = np.ones_like(mask1_flat, dtype=bool)
    else:
        raise ValueError("method must be 'overlap', 'union', or 'all'")
    
    mask1_valid = mask1_flat[valid_mask]
    mask2_valid = mask2_flat[valid_mask]
    
    # Check if we have enough data points
    if len(mask1_valid) < 2:
        return np.nan, np.nan
    
    # Calculate Spearman correlation
    correlation, p_value = spearmanr(mask1_valid, mask2_valid)
    
    return correlation, p_value

# %%
drawn_1s_img = nib.load(drawn_1s_fn)
atlas_1s_img = nib.load(atlas_1s_fn)
    
# Convert to arrays (masker already applies brain mask)
drawn_1s_arr = masker.transform(drawn_1s_img)
atlas_1s_arr = masker.transform(atlas_1s_img)
    
# Calculate Spearman correlation (masker already restricts to brain voxels)
correlation_1s, p_value_1s = spearman_correlation(drawn_1s_arr, atlas_1s_arr)
 
print(f"1-sample Spearman Correlation: {correlation_1s:.4f}")
print(f"1-sample p-value: {p_value_1s:.12f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 drawn_1s_img = nib.load(drawn_1s_fn)
#       2 atlas_1s_img = nib.load(atlas_1s_fn)
#       4 # Convert to arrays (masker already applies brain mask)
#
# NameError: name 'drawn_1s_fn' is not defined

# %%
drawn_2s_img = nib.load(drawn_2s_fn)
atlas_2s_img = nib.load(atlas_2s_fn)
    
# Convert to arrays (masker already applies brain mask)
drawn_2s_arr = masker.transform(drawn_2s_img)
atlas_2s_arr = masker.transform(atlas_2s_img)
    
# Calculate Spearman correlation (masker already restricts to brain voxels)
correlation_2s, p_value_2s = spearman_correlation(drawn_2s_arr, atlas_2s_arr)
 
print(f"2-sample Spearman Correlation: {correlation_2s:.4f}")
print(f"2-sample p-value: {p_value_2s:.12f}")
# Out:
# /Users/chloehampson/Desktop/habenula-comparison/.venv/lib/python3.9/site-packages/nilearn/maskers/nifti_masker.py:108: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   warnings.warn(
# /Users/chloehampson/Desktop/habenula-comparison/.venv/lib/python3.9/site-packages/nilearn/maskers/nifti_masker.py:108: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   warnings.warn(
# 2-sample Spearman Correlation: 0.9469
# 2-sample p-value: 0.000000000000
